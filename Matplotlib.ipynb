# %% [markdown]
# Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Plotting x and y

# %%
x=np.array([1,2,3,4,5])
y=np.array([10,20,30,40,50])
plt.plot(x,y)
plt.show()

# %% [markdown]
# Matplotlib offers extensive customization for line Charts

# %%
x=[1,2,3,4,5]
y=[1,4,9,16,25]
plt.figure(figsize=(8,5))
plt.plot(x,y,color='green',linewidth=3,marker='s',linestyle='--')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Chart')
plt.legend(['My Data Series'])
plt.grid(True)
plt.show()

# %% [markdown]
# Bar Chart

# %%
categories=['A','B','C','D','E']
values=[5,2,3,4,6]
plt.figure(figsize=(8,5))
plt.bar(categories,values,color='blue')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart')
plt.show()

# %% [markdown]
# Histogram

# %%
data=[12,15,13,17,16,16,19,12,14,16,17,18,18,15,14]
plt.hist(data,bins=15,edgecolor='black')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %% [markdown]
# Scatter plot

# %%
x=[1,2,3,4,5]
y=[5,7,4,6,8]
plt.scatter(x,y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot')
plt.show()

# %% [markdown]
# Pie Chart

# %%
labels=['A','B','C','D','E']
sizes=[5,2,3,4,6]
plt.pie(sizes,labels=labels,autopct='%1.1f%%',startangle=90)
plt.title('Pie Chart')
plt.axis('equal')
plt.show()

# %% [markdown]
# Box plot

# %%
data=[7,8,4,5,6,9,12,5,7,8,6]
plt.boxplot(data)
plt.ylabel('Values')
plt.title('Box Plot')
plt.show()

# %% [markdown]
# Heatmap

# %%
data=np.random.rand(10,10)
plt.imshow(data,cmap='coolwarm',interpolation='nearest')
plt.colorbar()
plt.title('Heat Map')
plt.show()
